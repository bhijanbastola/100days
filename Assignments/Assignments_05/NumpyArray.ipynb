# %%
import numpy as np

# %%
array_1D=np.array([1,2,3,4,5])

# %%
array_1D
# Out:
# array([1, 2, 3, 4, 5])

# %%
array_2D=np.random.randint(1,9,size=(3,3))

# %%
array_2D
# Out:
# array([[2, 3, 8],
#        [6, 4, 1],
#        [5, 1, 7]])

# %%
arr = np.linspace(0, 5, 10)

# %%
arr
# Out:
# array([0.        , 0.55555556, 1.11111111, 1.66666667, 2.22222222,
#        2.77777778, 3.33333333, 3.88888889, 4.44444444, 5.        ])
