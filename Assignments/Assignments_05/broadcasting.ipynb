# %%
import numpy as np

# %%
arr1=np.ones((3,3))

# %%
arr1
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
arr2=np.array([1,2,3])

# %%
arr2
# Out:
# array([1, 2, 3])

# %%
np.add(arr1,arr2)
# Out:
# array([[2., 3., 4.],
#        [2., 3., 4.],
#        [2., 3., 4.]])
