# %%
import numpy as np

# %% [markdown]
# Find the shape, size, and data type of the 2D array.

# %%
array_2D=np.random.randint(1,9,size=(3,3))

# %%
array_2D.shape
# Out:
# (3, 3)

# %%
array_2D.size
# Out:
# 9

# %%
array_2D.dtype
# Out:
# dtype('int64')

# %% [markdown]
# Change the 1D array into a 2D array of shape (5,1).

# %%
arr=np.array([1,2,3,4,5
              ])

# %%
arr.reshape(5,1)
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5]])

# %% [markdown]
# Flatten a multi-dimensional array back into a 1D array.

# %%
res=array_2D.flatten()

# %%
res
# Out:
# array([4, 3, 6, 2, 3, 8, 3, 3, 1])
