# %%
import numpy as np

# %% [markdown]
# Element wise operations

# %%
a=np.array([

    [4,6,8],
    [1,2,4],
])
b=np.random.randint(1,45,size=(2,3))
c=np.linspace((0,5),(60,100),num=7)

# %%
np.add(a,b)
# Out:
# array([[29, 18,  9],
#        [37, 42, 27]])

# %%
np.subtract(a,b)
# Out:
# array([[-21,  -6,   7],
#        [-35, -38, -19]])

# %%
np.pow(a,2)
# Out:
# array([[16, 36, 64],
#        [ 1,  4, 16]])

# %%
quo,rem=np.divmod(b,a)

# %%
rem
# Out:
# array([[1, 0, 1],
#        [0, 0, 3]])

# %%
quo
# Out:
# array([[ 6,  2,  0],
#        [36, 20,  5]])

# %% [markdown]
# Trignometry

# %%
np.sin(a)
# Out:
# array([[-0.7568025 , -0.2794155 ,  0.98935825],
#        [ 0.84147098,  0.90929743, -0.7568025 ]])

# %%
np.reciprocal(np.tan(b))
# Out:
# array([[-7.48915531, -1.57267341,  0.64209262],
#        [ 0.12902442, -0.89508292,  0.62966222]])

# %%
np.reciprocal(np.sin(b))
# Out:
# array([[-7.55562355, -1.8636796 ,  1.18839511],
#        [-1.00828929,  1.34207803, -1.18172523]])

# %% [markdown]
# Matrix Operations

# %%
#Transpose
bT=np.transpose(b)

# %%
#Matrix Multiplication
res=np.dot(a,bT)

# %%
#Trace -> sum of diagonal of a matrix
sum=np.trace(res)
print(sum)
# Out:
# 388

# %%
#Rank
np.linalg.matrix_rank(a)
# Out:
# np.int64(2)

# %%
#Determinant
b=np.random.randint(1,10,size=(3,3))
det_b=np.linalg.det(b)

# %%
#Inverse 
inv=np.linalg.inv(b)
# Out:
# array([[-0.09677419, -0.14516129,  0.27419355],
#        [ 0.61290323, -0.08064516, -0.40322581],
#        [-0.19354839,  0.20967742,  0.0483871 ]])

# %% [markdown]
# solve the equation:
# 4x+2y=8
# 5x=3y=9

# %%
A=np.array([[4,2],[5,3]])
b=np.array([[8],[9]])

# %%
A_inv=np.linalg.inv(A)

# %%
X=np.dot(A_inv,b)

# %%
X
# Out:
# array([[ 3.],
#        [-2.]])

# %%
solution = np.linalg.solve(A, b)

# %%
solution
# Out:
# array([[ 3.],
#        [-2.]])
