# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/Users/bhijanbastola/Desktop/intern/Data/smart_phone_addiction.csv")

# %%
df.drop(columns=["id"],inplace=True)

# %%
df.head()
# Out:
#     age  daily_screen_time_hours  social_media_hours  gaming_hours  \
# 0  24.0                      NaN                1.83          1.59
# 1  19.0                     5.97                1.08           NaN
# 2  18.0                     5.09                 NaN           NaN
# 3  21.0                     6.42                1.26          1.42
# 4  26.0                    11.20                1.87          2.81
#
#    work_study_hours  sleep_hours  notifications_per_day  app_opens_per_day  \
# 0              2.11         7.46                  122.0               38.0
# 1              3.03         8.22                   76.0               19.0
# 2               NaN         6.25                  134.0               60.0
# 3              3.36         8.85                  112.0               94.0
# 4              1.95         5.25                    NaN                NaN
#
#    weekend_screen_time  gender stress_level academic_work_impact  \
# 0                 8.63    Male       Medium                   No
# 1                  NaN  Female       Medium                   No
# 2                 7.47  Female          Low                  Yes
# 3                 8.66   Other          Low                  NaN
# 4                13.39  Female       Medium                   No
#
#    addicted_label
# 0               1
# 1               0
# 2               0
# 3               1
# 4               1

# %%
df.shape
# Out:
# (691369, 13)

# %%
sns.countplot(df,x="gender")

# %%
sns.countplot(df,x="stress_level")

# %%
numerical_cols = [
    'daily_screen_time_hours',
    'social_media_hours',
    'gaming_hours',
    'work_study_hours',
    'sleep_hours',
    'notifications_per_day',
    'app_opens_per_day',
    'weekend_screen_time',
    'age'
]

# %%
for col in numerical_cols:
    plt.figure(figsize=(7, 5))
    sns.boxplot(data=df, x='addicted_label', y=col)
    plt.title(f'{col} vs Addiction')
    plt.xlabel('Addicted Label')
    plt.ylabel(col)
    plt.show()

# %%
for col in numerical_cols:
    plt.figure(figsize=(7, 5))
    sns.histplot(data=df, x=col, hue='addicted_label', kde=True)
    plt.title(f'{col} Distribution by Addiction')
    plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.show()

# %%
df.dropna(thresh=8,inplace=True)

# %%
df.isna().sum()
# Out:
# age                         27095
# daily_screen_time_hours     90608
# social_media_hours         128251
# gaming_hours               121150
# work_study_hours            48878
# sleep_hours                 41065
# notifications_per_day       63357
# app_opens_per_day           76178
# weekend_screen_time        106522
# gender                      27161
# stress_level                51288
# academic_work_impact        40902
# addicted_label                  0
# dtype: int64

# %%
df["entertainment_hours"] = (
    df["social_media_hours"] +
    df["gaming_hours"]
)


df["entertainment_ratio"] = (
    df["entertainment_hours"] /
    (df["daily_screen_time_hours"] + 0.01)
)


df["social_media_ratio"] = (
    df["social_media_hours"] /
    (df["daily_screen_time_hours"] + 0.01)
)


df["gaming_ratio"] = (
    df["gaming_hours"] /
    (df["daily_screen_time_hours"] + 0.01)
)


df["work_study_ratio"] = (
    df["work_study_hours"] /
    (df["daily_screen_time_hours"] + 0.01)
)


df["weekend_screen_ratio"] = (
    df["weekend_screen_time"] /
    (df["daily_screen_time_hours"] + 0.01)
)


df["weekend_screen_difference"] = (
    df["weekend_screen_time"] -
    df["daily_screen_time_hours"]
)


df["recreational_to_work_ratio"] = (
    df["entertainment_hours"] /
    (df["work_study_hours"] + 0.01)
)


df["social_gaming_interaction"] = (
    df["social_media_hours"] *
    df["gaming_hours"]
)


df["sleep_screen_ratio"] = (
    df["sleep_hours"] /
    (df["daily_screen_time_hours"] + 0.01)
)

# %%
df.head()
# Out:
#     age  daily_screen_time_hours  social_media_hours  gaming_hours  \
# 0  24.0                      NaN                1.83          1.59
# 1  19.0                     5.97                1.08           NaN
# 2  18.0                     5.09                 NaN           NaN
# 3  21.0                     6.42                1.26          1.42
# 4  26.0                    11.20                1.87          2.81
#
#    work_study_hours  sleep_hours  notifications_per_day  app_opens_per_day  \
# 0              2.11         7.46                  122.0               38.0
# 1              3.03         8.22                   76.0               19.0
# 2               NaN         6.25                  134.0               60.0
# 3              3.36         8.85                  112.0               94.0
# 4              1.95         5.25                    NaN                NaN
#
#    weekend_screen_time  gender  ... entertainment_hours entertainment_ratio  \
# 0                 8.63    Male  ...                3.42                 NaN
# 1                  NaN  Female  ...                 NaN                 NaN
# 2                 7.47  Female  ...                 NaN                 NaN
# 3                 8.66   Other  ...                2.68            0.416796
# 4                13.39  Female  ...                4.68            0.417484
#
#    social_media_ratio  gaming_ratio  work_study_ratio  weekend_screen_ratio  \
# 0                 NaN           NaN               NaN                   NaN
# 1            0.180602           NaN          0.506689                   NaN
# 2                 NaN           NaN               NaN              1.464706
# 3            0.195956      0.220840          0.522551              1.346812
# 4            0.166815      0.250669          0.173952              1.194469
#
#    weekend_screen_difference  recreational_to_work_ratio  \
# 0                        NaN                    1.613208
# 1                        NaN                         NaN
# 2                       2.38                         NaN
# 3                       2.24                    0.795252
# 4                       2.19                    2.387755
#
#    social_gaming_interaction  sleep_screen_ratio
# 0                     2.9097                 NaN
# 1                        NaN            1.374582
# 2                        NaN            1.225490
# 3                     1.7892            1.376361
# 4                     5.2547            0.468332
#
# [5 rows x 23 columns]
