# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data={
    "name":["bhijan","hulash","Dipesh "],
    "age":[20,25,30]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       name  age
# 0   bhijan   20
# 1   hulash   25
# 2  Dipesh    30

# %%
X=df.name
y=df.age
