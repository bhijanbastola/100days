# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/Users/bhijanbastola/Desktop/intern/Data/train-2.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked
# 0      0         A/5 21171   7.2500  B96 B98        S
# 1      0          PC 17599  71.2833      C85        C
# 2      0  STON/O2. 3101282   7.9250  B96 B98        S
# 3      0            113803  53.1000     C123        S
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df.loc[2,"Age"]
# Out:
# np.float64(26.0)

# %%
#Conditional Based Filtering
mask=df.Fare>100
fare_100=df[mask]
fare_100.shape
# Out:
# (53, 12)

# %% [markdown]
# Outof 891 passenger 53 where passenger with tickets greater than 100

# %%
fare_100["Sex"].value_counts()
# Out:
# Sex
# female    34
# male      19
# Name: count, dtype: int64

# %% [markdown]
# out of 53 high paying passenger 34 were female and 19 were male

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df['Cabin'] = df['Cabin'].fillna(df['Cabin'].mode()[0])

# %%
df = df.dropna(subset=['Embarked'])

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.duplicated().value_counts()
# Out:
# False    889
# Name: count, dtype: int64

# %%
numeric_colums=['Age','SibSp','Parch','Fare']
for columns in numeric_colums:
  plt.figure(figsize=(6,4))
  sns.boxplot(x=df[columns])
  plt.title(f'Distribution of {columns}')
  plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.show()

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
numeric_colums=['Age','SibSp','Parch','Fare']
for columns in numeric_colums:
  plt.figure(figsize=(6,4))
  sns.histplot(df[columns],kde=True,bins=20)
  plt.title(f'Distribution of {columns}')
  plt.show()

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    340
# Name: count, dtype: int64

# %%
survival_High=df[(df.Pclass==1)&(df.Survived==1)]
survival_High

# %%
print(f'134 were high paying passenger who survived {(134/340)*100} is the percentage of survival')
# Out:
# 134 were high paying passenger who survived 39.411764705882355 is the percentage of survival
