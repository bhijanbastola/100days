# %%
import numpy as np

# %%
arr=np.random.randint(0,10,size=(5,4))
arr
# Out:
# array([[4, 7, 0, 6],
#        [3, 8, 7, 4],
#        [5, 0, 0, 7],
#        [4, 7, 7, 5],
#        [2, 2, 4, 9]])

# %%
arr[2,-1]
# Out:
# np.int64(7)

# %%
arr[-1,-1]
# Out:
# np.int64(9)

# %%
#Slicing 2D array

# %%
arr[1:4,2:]
# Out:
# array([[7, 4],
#        [0, 7],
#        [7, 5]])

# %%
arr[:,-2:]
# Out:
# array([[0, 6],
#        [7, 4],
#        [0, 7],
#        [7, 5],
#        [4, 9]])

# %%
arr[2:4,1:-1]
# Out:
# array([[0, 0],
#        [7, 7]])

# %%
#3D array
np.random.seed(99)
arr1=np.random.randint(0,10,size=(3,4,3))
arr1

# %%
#Indexing
arr1[:,:,-1]
# Out:
# array([[7, 9, 0, 3]])

# %%
arr1[: , : ,-1:]
# Out:
# array([[[9],
#         [8],
#         [5],
#         [7]],
#
#        [[1],
#         [6],
#         [2],
#         [8]],
#
#        [[7],
#         [9],
#         [0],
#         [3]]])

# %%
import pandas as pd
