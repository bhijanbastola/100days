# %%
import pandas as pd

titanic_df = pd.read_csv("../clean_titanic_dataset.csv")

titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0       0.0     3.0                            Braund, Mr. Owen Harris
# 1       1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       1.0     3.0                             Heikkinen, Miss. Laina
# 3       1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       0.0     3.0                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare  Cabin Embarked  \
# 0    male  22.0    1.0    0.0         A/5 21171   7.2500      0        S
# 1  female  38.0    1.0    0.0          PC 17599  71.2833      1        C
# 2  female  26.0    0.0    0.0  STON/O2. 3101282   7.9250      0        S
# 3  female  35.0    1.0    0.0            113803  53.1000      1        S
# 4    male  35.0    0.0    0.0            373450   8.0500      0        S
#
#   initials
# 0       Mr
# 1      Mrs
# 2     Miss
# 3      Mrs
# 4       Mr

# %% [markdown]
# # Data Encoding
#
# Data Encoding is a technique that is used to convert categorical columns into numerical ones so that they can be fitted by machine learning models which only take numerical data. It is an important pre-processing step in a machine-learning project.

# %% [markdown]
# ### Nominal and Ordinal Data
#
# ![image.png](attachment:ea522df6-c44e-4d23-a65e-45547f7be277.png)

# %%
### Nominal Data  -> data without natural order
titanic_df.Sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 869      male
# 870    female
# 871    female
# 872      male
# 873      male
# Name: Sex, Length: 874, dtype: str

# %% [markdown]
# ### One- Hot Encoding

# %%
# Pandas
pd.get_dummies(titanic_df, columns=["Sex","Embarked"], dtype=int).head(5)
# Out:
#    Survived  Pclass                                               Name   Age  \
# 0       0.0     3.0                            Braund, Mr. Owen Harris  22.0
# 1       1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2       1.0     3.0                             Heikkinen, Miss. Laina  26.0
# 3       1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4       0.0     3.0                           Allen, Mr. William Henry  35.0
#
#    SibSp  Parch            Ticket     Fare  Cabin initials  Sex_female  \
# 0    1.0    0.0         A/5 21171   7.2500      0       Mr           0
# 1    1.0    0.0          PC 17599  71.2833      1      Mrs           1
# 2    0.0    0.0  STON/O2. 3101282   7.9250      0     Miss           1
# 3    1.0    0.0            113803  53.1000      1      Mrs           1
# 4    0.0    0.0            373450   8.0500      0       Mr           0
#
#    Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0         1           0           0           1
# 1         0           1           0           0
# 2         0           0           0           1
# 3         0           0           0           1
# 4         1           0           0           1

# %%
# !pip install scikit-learn
import sklearn
sklearn.show_versions()
# Out:
# System:
#     python: 3.12.13 (main, May  6 2026, 18:46:41) [GCC 15.2.0]
# executable: /home/shailesh/Desktop/education/.venv/bin/python3.12
#    machine: Linux-7.0.0-30-generic-x86_64-with-glibc2.43
#
# Python dependencies:
#       sklearn: 1.9.0
#           pip: 26.1.2
#    setuptools: 81.0.0
#         numpy: 2.4.6
#         scipy: 1.17.1
#        Cython: None
#        pandas: 3.0.3
#    matplotlib: 3.11.0
#        joblib: 1.5.3
# threadpoolctl: 3.6.0
#      narwhals: 2.22.1
#
# Built with OpenMP: True
#
# threadpoolctl info:
#        user_api: blas
#    internal_api: openblas
#     num_threads: 20
#          prefix: libscipy_openblas
#        filepath: /home/shailesh/Desktop/education/.venv/lib/python3.12/site-packages/numpy.libs/libscipy_openblas64_-32a4b2a6.so
#         version: 0.3.31.188.0
# threading_layer: pthreads
#    architecture: Haswell
#
#        user_api: blas
#    internal_api: openblas
#     num_threads: 20
#          prefix: libscipy_openblas
#        filepath: /home/shailesh/Desktop/education/.venv/lib/python3.12/site-packages/scipy.libs/libscipy_openblas-6cdc3b4a.so
#         version: 0.3.30
# threading_layer: pthreads
#    architecture: Haswell
#
#        user_api: openmp
#    internal_api: openmp
#     num_threads: 20
#          prefix: libgomp
#        filepath: /home/shailesh/Desktop/education/.venv/lib/python3.12/site-packages/scikit_learn.libs/libgomp-e985bcbb.so.1.0.0
#         version: None
